# %% [raw]
# ---
# title: mercury test
# description: test for mercury
# show-code: False
# params:
#     npower:
#         input: numeric
#         label: choose the nth-power
#         value: 3
#         min: 0
#         max: 5
# ---

# %% [markdown]
# # test

# %%
npower = 3

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

size = 50

x = np.linspace(0, 20, size)
y = x + 1 + x**npower

fig = plt.figure()
plt.plot(x, y)
plt.show()
plt.close()
